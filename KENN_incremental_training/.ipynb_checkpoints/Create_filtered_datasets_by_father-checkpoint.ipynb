# %%
base_dataset_path = '../../datasets/ren_et_al/'

dataset_name_path = 'figer/'

types_list_path = 'all_types.txt'

train_path = 'train.json'
dev_path = 'dev.json'
test_path = 'test.json'

dir_for_partitioned_datasets = '../../datasets/datasets_for_incremental_training/'

# %%
# import types
with open(base_dataset_path + dataset_name_path + types_list_path, 'r') as inp:
    types_list = [l.replace('\n', '') for l in inp.readlines()]
types_list
# Out:
# ['/art',
#  '/art/film',
#  '/astral_body',
#  '/award',
#  '/biology',
#  '/body_part',
#  '/broadcast',
#  '/broadcast/tv_channel',
#  '/broadcast_network',
#  '/broadcast_program',
#  '/building',
#  '/building/airport',
#  '/building/dam',
#  '/building/hospital',
#  '/building/hotel',
#  '/building/library',
#  '/building/power_station',
#  '/building/restaurant',
#  '/building/sports_facility',
#  '/building/theater',
#  '/chemistry',
#  '/computer',
#  '/computer/algorithm',
#  '/computer/programming_language',
#  '/disease',
#  '/education',
#  '/education/department',
#  '/education/educational_degree',
#  '/event',
#  '/event/attack',
#  '/event/election',
#  '/event/military_conflict',
#  '/event/natural_disaster',
#  '/event/protest',
#  '/event/sports_event',
#  '/event/terrorist_attack',
#  '/finance',
#  '/finance/currency',
#  '/finance/stock_exchange',
#  '/food',
#  '/game',
#  '/geography',
#  '/geography/glacier',
#  '/geography/island',
#  '/geography/mountain',
#  '/god',
#  '/government',
#  '/government/government',
#  '/government/political_party',
#  '/government_agency',
#  '/internet',
#  '/internet/website',
#  '/language',
#  '/law',
#  '/living_thing',
#  '/living_thing/animal',
#  '/location',
#  '/location/body_of_water',
#  '/location/bridge',
#  '/location/cemetery',
#  '/location/city',
#  '/location/country',
#  '/location/county',
#  '/location/province',
#  '/medicine',
#  '/medicine/drug',
#  '/medicine/medical_treatment',
#  '/medicine/symptom',
#  '/metropolitan_transit',
#  '/metropolitan_transit/transit_line',
#  '/military',
#  '/music',
#  '/news_agency',
#  '/newspaper',
#  '/organization',
#  '/organization/airline',
#  '/organization/company',
#  '/organization/educational_institution',
#  '/organization/fraternity_sorority',
#  '/organization/sports_league',
#  '/organization/sports_team',
#  '/organization/terrorist_organization',
#  '/park',
#  '/people',
#  '/people/ethnicity',
#  '/person',
#  '/person/actor',
#  '/person/architect',
#  '/person/artist',
#  '/person/athlete',
#  '/person/author',
#  '/person/coach',
#  '/person/director',
#  '/person/doctor',
#  '/person/engineer',
#  '/person/monarch',
#  '/person/musician',
#  '/person/politician',
#  '/person/religious_leader',
#  '/person/soldier',
#  '/person/terrorist',
#  '/play',
#  '/product',
#  '/product/airplane',
#  '/product/camera',
#  '/product/car',
#  '/product/computer',
#  '/product/engine_device',
#  '/product/instrument',
#  '/product/mobile_phone',
#  '/product/ship',
#  '/product/spacecraft',
#  '/product/weapon',
#  '/rail',
#  '/rail/railway',
#  '/religion',
#  '/religion/religion',
#  '/software',
#  '/time',
#  '/title',
#  '/train',
#  '/transit',
#  '/transportation',
#  '/transportation/road',
#  '/visual_art',
#  '/visual_art/color',
#  '/written_work']

# %%
# read dataset
import json
with open(base_dataset_path + dataset_name_path + train_path, 'r') as inp:
    lines = [json.loads(l) for l in inp.readlines()]

# %%
len(lines)
# Out:
# 2676846

# %%
# declare types to filter
types_to_filter = ['/location']

# %%
from collections import defaultdict
from tqdm import tqdm

# create dataset with the examples annotated with only the types_to_filter 
# or annotated with other types that are not sons of types_to_filter

new_dataset_partitions = defaultdict(list)
new_dataset_partitions['only_father'] = defaultdict(list)
new_dataset_partitions['father_and_sons'] = defaultdict(list)

types_only_partitions = defaultdict(list)
types_only_partitions['only_father'] = defaultdict(list)                
types_only_partitions['father_and_sons'] = defaultdict(list)                

for l in tqdm(lines):
    line_types = l['y_str']
    if all([t not in line_types for t in types_to_filter]):
        new_dataset_partitions['disjoint'].append(l)
        types_only_partitions['disjoint'].append(line_types)
    else:
        for t in types_to_filter:
            if sum([t in line_type for line_type in line_types ]) == 1:
                new_dataset_partitions['only_father'][t].append(l)
                types_only_partitions['only_father'][t].append(line_types)
            else:
                for lt in line_types:
                    if t in lt and lt != t:
                        new_dataset_partitions['father_and_sons'][lt].append(l)
                        types_only_partitions['father_and_sons'][lt].append(line_types)
# Out:
#   0%|                                                                                                                                          | 7/2676846 [00:00<01:42, 26097.89it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_78040/2680938221.py in <module>
#      24                 for lt in line_types:
#      25                     if t in lt and lt != t:
# ---> 26                         new_dataset_partitions['father_and_sons'][lt].append(l)
#      27                         types_only_partitions['father_and_sons'][lt].append(line_types)
#      28
#
# TypeError: list indices must be integers or slices, not str

# %%
types_only_partitions
# Out:
# defaultdict(list,
#             {'only_father': defaultdict(list,
#                          {'/location': [['/location',
#                             '/metropolitan_transit',
#                             '/metropolitan_transit/transit_line'],
#                            ['/location'],
#                            ['/location',
#                             '/transportation',
#                             '/transportation/road'],
#                            ['/building',
#                             '/location',
#                             '/organization',
#                             '/organization/company'],
#                            ['/building', '/building/airport', '/location'],
#                            ['/building', '/location', '/park'],
#                            ['/location', '/news_agency', '/written_work'],
#                            ['/location'],
#                            ['/building', '/location'],
#                            ['/location',
#                             '/organization',
#                             '/organization/educational_institution'],
#                            ['/location',
#                             '/organization',
#                             '/organization/educational_institution'],
#                            ['/geography', '/geography/island', '/location'],
#                            ['/language', '/location'],
#                            ['/location',
#                             '/organization',
#                             '/organization/educational_institution'],
#                            ['/location',
#                             '/organization',
#                             '/organization/educational_institution'],
#                            ['/location', '/people', '/people/ethnicity'],
#                            ['/location'],
#                            ['/location', '/organization'],
#                            ['/location'],
#                            ['/building', '/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/building', '/location'],
#                            ['/location',
#                             '/organization',
#                             '/organization/educational_institution',
#                             '/person',
#                             '/person/author'],
#                            ['/location'],
#                            ['/location'],
#                            ['/art', '/building', '/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/building', '/location'],
#                            ['/location'],
#                            ['/location',
#                             '/organization',
#                             '/organization/company'],
#                            ['/location',
#                             '/organization',
#                             '/organization/educational_institution'],
#                            ['/location'],
#                            ['/location'],
#                            ['/building',
#                             '/building/sports_facility',
#                             '/location'],
#                            ['/broadcast_program', '/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location',
#                             '/organization',
#                             '/organization/educational_institution'],
#                            ['/location',
#                             '/organization',
#                             '/organization/company',
#                             '/organization/educational_institution'],
#                            ['/location'],
#                            ['/location',
#                             '/organization',
#                             '/organization/company',
#                             '/person',
#                             '/person/artist'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location',
#                             '/news_agency',
#                             '/organization',
#                             '/organization/company',
#                             '/written_work'],
#                            ['/location'],
#                            ['/location', '/organization'],
#                            ['/location'],
#                            ['/location'],
#                            ['/building', '/location'],
#                            ['/geography', '/geography/island', '/location'],
#                            ['/location',
#                             '/organization',
#                             '/organization/educational_institution'],
#                            ['/location',
#                             '/transportation',
#                             '/transportation/road'],
#                            ['/building', '/government_agency', '/location'],
#                            ['/building',
#                             '/building/sports_facility',
#                             '/location'],
#                            ['/building',
#                             '/location',
#                             '/organization',
#                             '/organization/educational_institution'],
#                            ['/location'],
#                            ['/building', '/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/building', '/location'],
#                            ['/building',
#                             '/location',
#                             '/organization',
#                             '/organization/educational_institution'],
#                            ['/location'],
#                            ['/geography', '/geography/island', '/location'],
#                            ['/location'],
#                            ['/building', '/location'],
#                            ['/location'],
#                            ['/geography', '/geography/island', '/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/building', '/building/theater', '/location'],
#                            ['/building', '/location'],
#                            ['/location'],
#                            ['/building',
#                             '/location',
#                             '/organization',
#                             '/organization/educational_institution'],
#                            ['/location'],
#                            ['/building',
#                             '/building/sports_facility',
#                             '/location'],
#                            ['/location', '/organization'],
#                            ['/building',
#                             '/building/sports_facility',
#                             '/location'],
#                            ['/building', '/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/building', '/building/hotel', '/location'],
#                            ['/location'],
#                            ['/location',
#                             '/organization',
#                             '/organization/educational_institution'],
#                            ['/location',
#                             '/organization',
#                             '/organization/company',
#                             '/organization/educational_institution'],
#                            ['/location'],
#                            ['/government_agency',
#                             '/location',
#                             '/military',
#                             '/organization'],
#                            ['/building',
#                             '/location',
#                             '/organization',
#                             '/organization/company'],
#                            ['/building',
#                             '/location',
#                             '/organization',
#                             '/organization/company'],
#                            ['/location'],
#                            ['/location',
#                             '/organization',
#                             '/organization/educational_institution'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location',
#                             '/organization',
#                             '/organization/company',
#                             '/person',
#                             '/person/engineer'],
#                            ['/location',
#                             '/organization',
#                             '/organization/educational_institution'],
#                            ['/location',
#                             '/organization',
#                             '/organization/educational_institution'],
#                            ['/location'],
#                            ['/location'],
#                            ['/building',
#                             '/location',
#                             '/organization',
#                             '/organization/company'],
#                            ['/location'],
#                            ['/building', '/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/geography', '/geography/island', '/location'],
#                            ['/geography', '/geography/island', '/location'],
#                            ['/building',
#                             '/location',
#                             '/organization',
#                             '/organization/company',
#                             '/park'],
#                            ['/location'],
#                            ['/geography', '/geography/island', '/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/geography', '/geography/island', '/location'],
#                            ['/geography', '/geography/island', '/location'],
#                            ['/location',
#                             '/organization',
#                             '/organization/educational_institution'],
#                            ['/location'],
#                            ['/location', '/organization'],
#                            ['/location'],
#                            ['/building',
#                             '/location',
#                             '/organization',
#                             '/organization/company',
#                             '/person',
#                             '/person/artist',
#                             '/person/author'],
#                            ['/location'],
#                            ['/building', '/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location',
#                             '/organization',
#                             '/organization/company',
#                             '/organization/educational_institution'],
#                            ['/building', '/location'],
#                            ['/location'],
#                            ['/geography', '/geography/island', '/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location', '/organization'],
#                            ['/location'],
#                            ['/location', '/park'],
#                            ['/building', '/location'],
#                            ['/broadcast_network',
#                             '/location',
#                             '/news_agency',
#                             '/organization',
#                             '/organization/company',
#                             '/person',
#                             '/person/artist',
#                             '/person/author'],
#                            ['/geography', '/geography/island', '/location'],
#                            ['/geography', '/geography/mountain', '/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location',
#                             '/organization',
#                             '/organization/educational_institution'],
#                            ['/location'],
#                            ['/building', '/location', '/organization'],
#                            ['/location'],
#                            ['/location', '/written_work'],
#                            ['/location'],
#                            ['/building', '/location'],
#                            ['/location'],
#                            ['/geography', '/geography/island', '/location'],
#                            ['/building',
#                             '/location',
#                             '/organization',
#                             '/organization/company'],
#                            ['/building', '/location'],
#                            ['/building', '/location'],
#                            ['/location',
#                             '/organization',
#                             '/organization/educational_institution'],
#                            ['/location',
#                             '/organization',
#                             '/organization/educational_institution'],
#                            ['/location',
#                             '/organization',
#                             '/organization/company',
#                             '/organization/educational_institution',
#                             '/organization/sports_team'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location',
#                             '/organization',
#                             '/organization/company'],
#                            ['/building',
#                             '/location',
#                             '/organization',
#                             '/organization/company',
#                             '/written_work'],
#                            ['/location', '/written_work'],
#                            ['/language', '/location'],
#                            ['/location', '/written_work'],
#                            ['/location'],
#                            ['/location',
#                             '/transportation',
#                             '/transportation/road'],
#                            ['/location',
#                             '/transportation',
#                             '/transportation/road'],
#                            ['/location', '/people', '/people/ethnicity'],
#                            ['/location'],
#                            ['/building',
#                             '/location',
#                             '/organization',
#                             '/organization/company',
#                             '/written_work'],
#                            ['/location'],
#                            ['/location'],
#                            ['/broadcast_network',
#                             '/location',
#                             '/organization',
#                             '/organization/company',
#                             '/person',
#                             '/person/artist',
#                             '/person/engineer'],
#                            ['/building', '/location'],
#                            ['/building',
#                             '/building/sports_facility',
#                             '/location'],
#                            ['/location',
#                             '/organization',
#                             '/organization/company',
#                             '/person',
#                             '/person/artist'],
#                            ['/location', '/title'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location', '/park'],
#                            ['/broadcast_network',
#                             '/location',
#                             '/news_agency',
#                             '/organization',
#                             '/organization/company',
#                             '/person',
#                             '/person/artist',
#                             '/person/author'],
#                            ['/building', '/location'],
#                            ['/government_agency',
#                             '/location',
#                             '/organization',
#                             '/organization/educational_institution'],
#                            ['/location',
#                             '/organization',
#                             '/organization/educational_institution'],
#                            ['/location'],
#                            ['/location',
#                             '/organization',
#                             '/organization/company',
#                             '/organization/educational_institution',
#                             '/organization/sports_team'],
#                            ['/building', '/location'],
#                            ['/location'],
#                            ['/geography', '/geography/mountain', '/location'],
#                            ['/location',
#                             '/organization',
#                             '/organization/educational_institution'],
#                            ['/location'],
#                            ['/location'],
#                            ['/geography', '/geography/island', '/location'],
#                            ['/building',
#                             '/location',
#                             '/organization',
#                             '/organization/educational_institution'],
#                            ['/location',
#                             '/organization',
#                             '/organization/educational_institution'],
#                            ['/building',
#                             '/location',
#                             '/organization',
#                             '/organization/educational_institution'],
#                            ['/building', '/location'],
#                            ['/location',
#                             '/organization',
#                             '/organization/educational_institution'],
#                            ['/location'],
#                            ['/geography', '/geography/mountain', '/location'],
#                            ['/geography', '/geography/island', '/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/building', '/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location',
#                             '/news_agency',
#                             '/organization',
#                             '/organization/educational_institution'],
#                            ['/location'],
#                            ['/location', '/written_work'],
#                            ['/government',
#                             '/government/government',
#                             '/location',
#                             '/news_agency',
#                             '/organization',
#                             '/person',
#                             '/person/artist',
#                             '/person/author'],
#                            ['/location'],
#                            ['/location',
#                             '/organization',
#                             '/organization/educational_institution',
#                             '/person',
#                             '/person/author'],
#                            ['/location',
#                             '/organization',
#                             '/organization/educational_institution',
#                             '/organization/sports_team'],
#                            ['/astral_body', '/location'],
#                            ['/geography', '/geography/island', '/location'],
#                            ['/location',
#                             '/organization',
#                             '/organization/educational_institution'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location',
#                             '/organization',
#                             '/organization/educational_institution'],
#                            ['/location',
#                             '/organization',
#                             '/organization/educational_institution'],
#                            ['/location',
#                             '/organization',
#                             '/organization/educational_institution',
#                             '/person',
#                             '/person/author'],
#                            ['/building',
#                             '/location',
#                             '/organization',
#                             '/organization/company',
#                             '/person',
#                             '/person/artist',
#                             '/person/author'],
#                            ['/location'],
#                            ['/building', '/location'],
#                            ['/location'],
#                            ['/event', '/location', '/park'],
#                            ['/building',
#                             '/location',
#                             '/news_agency',
#                             '/written_work'],
#                            ['/building', '/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/broadcast_network',
#                             '/location',
#                             '/organization',
#                             '/organization/company',
#                             '/person',
#                             '/person/artist',
#                             '/person/engineer'],
#                            ['/event', '/location'],
#                            ['/building', '/location'],
#                            ['/location', '/organization'],
#                            ['/location', '/people', '/people/ethnicity'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location',
#                             '/transportation',
#                             '/transportation/road'],
#                            ['/building',
#                             '/building/sports_facility',
#                             '/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/building', '/location'],
#                            ['/location'],
#                            ['/building',
#                             '/building/sports_facility',
#                             '/location'],
#                            ['/location',
#                             '/organization',
#                             '/organization/company'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/building', '/building/hotel', '/location'],
#                            ['/location',
#                             '/transportation',
#                             '/transportation/road'],
#                            ['/location'],
#                            ['/geography', '/geography/island', '/location'],
#                            ['/building', '/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location',
#                             '/organization',
#                             '/organization/company'],
#                            ['/location'],
#                            ['/location'],
#                            ['/building', '/location'],
#                            ['/location'],
#                            ['/location', '/people', '/people/ethnicity'],
#                            ['/location',
#                             '/organization',
#                             '/organization/company',
#                             '/organization/educational_institution',
#                             '/organization/sports_team'],
#                            ['/building', '/location', '/organization'],
#                            ['/location'],
#                            ['/building',
#                             '/building/sports_facility',
#                             '/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location',
#                             '/news_agency',
#                             '/organization',
#                             '/organization/company',
#                             '/person',
#                             '/person/author'],
#                            ['/building', '/location'],
#                            ['/building',
#                             '/building/sports_facility',
#                             '/location'],
#                            ['/building', '/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location', '/title'],
#                            ['/building',
#                             '/location',
#                             '/organization',
#                             '/organization/company'],
#                            ['/geography', '/geography/island', '/location'],
#                            ['/building',
#                             '/building/sports_facility',
#                             '/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/building',
#                             '/location',
#                             '/organization',
#                             '/organization/company'],
#                            ['/language', '/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/astral_body', '/location'],
#                            ['/location', '/organization'],
#                            ['/building', '/location'],
#                            ['/geography', '/geography/island', '/location'],
#                            ['/location',
#                             '/organization',
#                             '/organization/educational_institution'],
#                            ['/building',
#                             '/building/theater',
#                             '/location',
#                             '/organization',
#                             '/organization/company'],
#                            ['/location'],
#                            ['/location',
#                             '/person',
#                             '/person/actor',
#                             '/person/artist'],
#                            ['/location'],
#                            ['/building', '/location', '/organization'],
#                            ['/location'],
#                            ['/geography', '/geography/island', '/location'],
#                            ['/location',
#                             '/organization',
#                             '/organization/educational_institution'],
#                            ['/building', '/location'],
#                            ['/building', '/building/hotel', '/location'],
#                            ['/geography', '/geography/island', '/location'],
#                            ['/location'],
#                            ['/building',
#                             '/building/sports_facility',
#                             '/location'],
#                            ['/location',
#                             '/organization',
#                             '/organization/educational_institution'],
#                            ['/location',
#                             '/organization',
#                             '/organization/educational_institution'],
#                            ['/location',
#                             '/organization',
#                             '/organization/company',
#                             '/organization/educational_institution'],
#                            ['/location',
#                             '/organization',
#                             '/organization/educational_institution'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location',
#                             '/organization',
#                             '/organization/company',
#                             '/organization/educational_institution',
#                             '/written_work'],
#                            ['/building',
#                             '/location',
#                             '/organization',
#                             '/organization/sports_team'],
#                            ['/location'],
#                            ['/broadcast_network',
#                             '/location',
#                             '/news_agency',
#                             '/organization',
#                             '/organization/company',
#                             '/person',
#                             '/person/artist',
#                             '/person/author'],
#                            ['/location'],
#                            ['/location',
#                             '/transportation',
#                             '/transportation/road'],
#                            ['/location'],
#                            ['/building', '/building/theater', '/location'],
#                            ['/location',
#                             '/organization',
#                             '/organization/company',
#                             '/person',
#                             '/person/artist'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location',
#                             '/organization',
#                             '/organization/educational_institution'],
#                            ['/location'],
#                            ['/geography', '/geography/island', '/location'],
#                            ['/location'],
#                            ['/astral_body', '/location'],
#                            ['/location',
#                             '/organization',
#                             '/organization/company',
#                             '/rail',
#                             '/rail/railway'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location',
#                             '/organization',
#                             '/organization/educational_institution'],
#                            ['/building',
#                             '/location',
#                             '/organization',
#                             '/organization/educational_institution',
#                             '/person',
#                             '/person/author'],
#                            ['/location',
#                             '/organization',
#                             '/organization/company',
#                             '/rail',
#                             '/rail/railway'],
#                            ['/location'],
#                            ['/geography', '/geography/mountain', '/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/geography', '/geography/mountain', '/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/geography', '/geography/island', '/location'],
#                            ['/building', '/location'],
#                            ['/building', '/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/astral_body', '/location'],
#                            ['/building',
#                             '/building/theater',
#                             '/location',
#                             '/organization'],
#                            ['/location'],
#                            ['/location',
#                             '/transportation',
#                             '/transportation/road'],
#                            ['/location', '/people', '/people/ethnicity'],
#                            ['/location',
#                             '/organization',
#                             '/organization/company',
#                             '/organization/educational_institution'],
#                            ['/building', '/location'],
#                            ['/location',
#                             '/organization',
#                             '/organization/company',
#                             '/person',
#                             '/person/author'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/geography', '/geography/island', '/location'],
#                            ['/location'],
#                            ['/astral_body', '/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/building',
#                             '/building/sports_facility',
#                             '/location'],
#                            ['/location',
#                             '/news_agency',
#                             '/organization',
#                             '/organization/company',
#                             '/person',
#                             '/person/author'],
#                            ['/location',
#                             '/organization',
#                             '/organization/educational_institution'],
#                            ['/astral_body', '/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/building', '/location'],
#                            ['/location'],
#                            ['/building', '/location'],
#                            ['/location'],
#                            ['/location',
#                             '/organization',
#                             '/organization/company',
#                             '/organization/educational_institution',
#                             '/organization/sports_league'],
#                            ['/government',
#                             '/government/government',
#                             '/location',
#                             '/news_agency',
#                             '/organization',
#                             '/person',
#                             '/person/artist',
#                             '/person/author'],
#                            ['/building',
#                             '/location',
#                             '/organization',
#                             '/person'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/building', '/location'],
#                            ['/location'],
#                            ['/building',
#                             '/location',
#                             '/organization',
#                             '/organization/company',
#                             '/person',
#                             '/person/artist',
#                             '/person/author'],
#                            ['/building', '/building/theater', '/location'],
#                            ['/government_agency', '/location'],
#                            ['/location', '/people', '/people/ethnicity'],
#                            ['/building', '/location'],
#                            ['/location',
#                             '/organization',
#                             '/organization/educational_institution'],
#                            ['/building', '/building/hotel', '/location'],
#                            ['/building', '/location', '/park'],
#                            ['/location'],
#                            ['/building', '/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/geography', '/geography/island', '/location'],
#                            ['/geography', '/geography/island', '/location'],
#                            ['/location'],
#                            ['/location',
#                             '/organization',
#                             '/organization/educational_institution'],
#                            ['/location',
#                             '/transportation',
#                             '/transportation/road'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/building', '/location'],
#                            ['/location'],
#                            ['/location', '/written_work'],
#                            ['/location',
#                             '/organization',
#                             '/organization/educational_institution'],
#                            ['/location',
#                             '/organization',
#                             '/organization/educational_institution'],
#                            ['/building',
#                             '/building/sports_facility',
#                             '/location'],
#                            ['/location',
#                             '/organization',
#                             '/organization/educational_institution'],
#                            ['/location',
#                             '/organization',
#                             '/organization/educational_institution'],
#                            ['/location',
#                             '/organization',
#                             '/organization/educational_institution'],
#                            ['/location',
#                             '/organization',
#                             '/organization/company',
#                             '/organization/educational_institution'],
#                            ['/location'],
#                            ['/geography', '/geography/island', '/location'],
#                            ['/location'],
#                            ['/building',
#                             '/building/hospital',
#                             '/location',
#                             '/organization',
#                             '/organization/educational_institution'],
#                            ['/location'],
#                            ['/location'],
#                            ['/building', '/location'],
#                            ['/geography', '/geography/island', '/location'],
#                            ['/geography',
#                             '/geography/island',
#                             '/geography/mountain',
#                             '/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location',
#                             '/transportation',
#                             '/transportation/road'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/building', '/location'],
#                            ['/location',
#                             '/organization',
#                             '/organization/company',
#                             '/organization/educational_institution'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/geography', '/geography/mountain', '/location'],
#                            ['/building', '/location'],
#                            ['/building', '/location', '/organization'],
#                            ['/building', '/location', '/organization'],
#                            ['/location',
#                             '/organization',
#                             '/organization/company',
#                             '/organization/educational_institution'],
#                            ['/location',
#                             '/organization',
#                             '/organization/educational_institution'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location',
#                             '/organization',
#                             '/organization/company',
#                             '/organization/educational_institution',
#                             '/organization/sports_team'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location',
#                             '/organization',
#                             '/organization/educational_institution',
#                             '/person',
#                             '/person/author'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location',
#                             '/organization',
#                             '/organization/educational_institution'],
#                            ['/location',
#                             '/organization',
#                             '/organization/company',
#                             '/person',
#                             '/person/artist'],
#                            ['/location'],
#                            ['/building', '/location'],
#                            ['/building', '/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location', '/people', '/people/ethnicity'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/geography', '/geography/mountain', '/location'],
#                            ['/location', '/rail', '/rail/railway'],
#                            ['/location'],
#                            ['/location',
#                             '/organization',
#                             '/organization/educational_institution'],
#                            ['/location'],
#                            ['/geography', '/geography/mountain', '/location'],
#                            ['/geography', '/geography/mountain', '/location'],
#                            ['/geography', '/geography/mountain', '/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location', '/rail', '/rail/railway'],
#                            ['/location'],
#                            ['/location'],
#                            ['/language', '/location'],
#                            ['/location',
#                             '/organization',
#                             '/organization/educational_institution'],
#                            ['/location'],
#                            ['/location'],
#                            ['/geography', '/geography/mountain', '/location'],
#                            ['/location'],
#                            ['/geography', '/geography/mountain', '/location'],
#                            ['/location'],
#                            ['/building', '/location'],
#                            ['/government_agency', '/location'],
#                            ['/broadcast_network',
#                             '/location',
#                             '/news_agency',
#                             '/organization',
#                             '/organization/company',
#                             '/person',
#                             '/person/artist',
#                             '/person/author'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location',
#                             '/transportation',
#                             '/transportation/road'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/geography', '/geography/island', '/location'],
#                            ['/location', '/park'],
#                            ['/location',
#                             '/organization',
#                             '/organization/company',
#                             '/transportation',
#                             '/transportation/road'],
#                            ['/location'],
#                            ['/building', '/location', '/park'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/building', '/building/hospital', '/location'],
#                            ['/location',
#                             '/organization',
#                             '/organization/educational_institution'],
#                            ['/location',
#                             '/organization',
#                             '/organization/educational_institution'],
#                            ['/building', '/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/building', '/location'],
#                            ['/location'],
#                            ['/geography', '/geography/mountain', '/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location', '/people', '/people/ethnicity'],
#                            ['/location'],
#                            ['/location'],
#                            ['/location'],
# ...
#               ['/person', '/person/actor', '/person/artist'],
#               ['/person', '/person/artist'],
#               ['/person', '/person/actor', '/person/artist'],
#               ['/music'],
#               ['/music'],
#               ['/organization', '/organization/company'],
#               ['/event',
#                '/person',
#                '/person/actor',
#                '/person/artist',
#                '/person/author',
#                '/person/musician'],
#               ['/person',
#                '/person/actor',
#                '/person/artist',
#                '/person/author',
#                '/person/musician'],
#               ['/music'],
#               ['/music'],
#               ['/person', '/person/artist', '/person/author'],
#               ['/person', '/person/actor', '/person/artist'],
#               ['/music'],
#               ['/organization', '/organization/company'],
#               ['/organization',
#                '/organization/company',
#                '/person',
#                '/person/artist'],
#               ['/music'],
#               ['/person',
#                '/person/actor',
#                '/person/artist',
#                '/person/author',
#                '/person/musician'],
#               ['/music'],
#               ['/music'],
#               ['/event'],
#               ['/music'],
#               ['/art', '/art/film'],
#               ['/art', '/art/film'],
#               ['/art', '/art/film', '/organization', '/organization/company'],
#               ['/art', '/art/film'],
#               ['/art', '/art/film'],
#               ['/organization', '/organization/company'],
#               ['/person',
#                '/person/actor',
#                '/person/artist',
#                '/person/engineer',
#                '/person/musician'],
#               ['/event',
#                '/person',
#                '/person/actor',
#                '/person/artist',
#                '/person/author',
#                '/person/musician'],
#               ['/person', '/person/artist'],
#               ['/person', '/person/artist', '/person/musician'],
#               ['/broadcast_program'],
#               ['/person', '/person/artist', '/person/musician'],
#               ['/organization', '/organization/company'],
#               ['/person', '/person/actor', '/person/artist'],
#               ['/art', '/art/film'],
#               ['/art', '/art/film'],
#               ['/person', '/person/actor', '/person/artist'],
#               ['/person', '/person/artist'],
#               ['/person'],
#               ['/person', '/person/artist'],
#               ['/person', '/person/artist', '/person/musician'],
#               ['/organization'],
#               ['/person',
#                '/person/actor',
#                '/person/artist',
#                '/person/author',
#                '/person/musician'],
#               ['/person', '/person/artist', '/person/musician'],
#               ['/person',
#                '/person/artist',
#                '/person/author',
#                '/person/musician'],
#               ['/music'],
#               ['/person', '/person/artist'],
#               ['/music'],
#               ['/person', '/person/artist', '/person/musician'],
#               ['/person', '/person/actor', '/person/artist'],
#               ['/person', '/person/actor', '/person/artist'],
#               ['/person', '/person/artist'],
#               ['/organization', '/organization/company'],
#               ['/person', '/person/author'],
#               ['/written_work'],
#               ['/person', '/person/artist', '/person/musician'],
#               ['/music'],
#               ['/person',
#                '/person/actor',
#                '/person/artist',
#                '/person/author',
#                '/person/musician'],
#               ['/person',
#                '/person/actor',
#                '/person/artist',
#                '/person/musician'],
#               ['/person', '/person/artist', '/person/musician'],
#               ['/person',
#                '/person/actor',
#                '/person/artist',
#                '/person/author',
#                '/person/musician'],
#               ['/art', '/art/film'],
#               ['/person',
#                '/person/actor',
#                '/person/artist',
#                '/person/musician'],
#               ['/person',
#                '/person/actor',
#                '/person/artist',
#                '/person/athlete',
#                '/person/author',
#                '/person/musician'],
#               ['/broadcast_program'],
#               ['/person', '/person/actor', '/person/artist'],
#               ['/organization', '/organization/company'],
#               ['/music'],
#               ['/person',
#                '/person/actor',
#                '/person/artist',
#                '/person/author',
#                '/person/musician'],
#               ['/person',
#                '/person/actor',
#                '/person/artist',
#                '/person/author',
#                '/person/musician'],
#               ['/person', '/person/artist', '/person/musician'],
#               ['/person',
#                '/person/actor',
#                '/person/artist',
#                '/person/author',
#                '/person/musician'],
#               ['/person',
#                '/person/actor',
#                '/person/artist',
#                '/person/musician'],
#               ['/music'],
#               ['/person',
#                '/person/actor',
#                '/person/artist',
#                '/person/author',
#                '/person/director'],
#               ['/music'],
#               ['/person',
#                '/person/actor',
#                '/person/artist',
#                '/person/author',
#                '/person/director'],
#               ['/music'],
#               ['/music'],
#               ['/person', '/person/artist'],
#               ['/person',
#                '/person/artist',
#                '/person/author',
#                '/person/musician'],
#               ['/music'],
#               ['/person', '/person/artist', '/person/musician'],
#               ['/music'],
#               ['/music'],
#               ['/organization', '/organization/company'],
#               ['/person', '/person/artist', '/person/musician'],
#               ['/person',
#                '/person/artist',
#                '/person/author',
#                '/person/musician'],
#               ['/person', '/person/artist', '/person/musician'],
#               ['/event'],
#               ['/person', '/person/artist', '/person/musician'],
#               ['/person',
#                '/person/actor',
#                '/person/artist',
#                '/person/author',
#                '/person/musician'],
#               ['/music'],
#               ['/person',
#                '/person/actor',
#                '/person/artist',
#                '/person/musician'],
#               ['/music'],
#               ['/person',
#                '/person/actor',
#                '/person/artist',
#                '/person/author',
#                '/person/musician'],
#               ['/music'],
#               ['/person',
#                '/person/actor',
#                '/person/artist',
#                '/person/musician'],
#               ['/person',
#                '/person/actor',
#                '/person/artist',
#                '/person/director'],
#               ['/art', '/art/film'],
#               ['/person',
#                '/person/actor',
#                '/person/artist',
#                '/person/musician'],
#               ['/person', '/person/author', '/person/politician'],
#               ['/person', '/person/author', '/person/politician'],
#               ['/person', '/person/author'],
#               ['/language'],
#               ['/person', '/person/artist'],
#               ['/music'],
#               ['/person', '/person/author', '/person/musician'],
#               ['/product'],
#               ['/person', '/person/artist'],
#               ['/music'],
#               ['/music'],
#               ['/person', '/person/artist', '/person/musician'],
#               ['/person',
#                '/person/actor',
#                '/person/artist',
#                '/person/author',
#                '/person/musician'],
#               ['/news_agency',
#                '/organization',
#                '/organization/company',
#                '/person',
#                '/person/director',
#                '/person/engineer',
#                '/written_work'],
#               ['/person',
#                '/person/artist',
#                '/person/author',
#                '/person/musician'],
#               ['/person', '/person/musician'],
#               ['/person',
#                '/person/actor',
#                '/person/artist',
#                '/person/musician'],
#               ['/music'],
#               ['/person',
#                '/person/actor',
#                '/person/artist',
#                '/person/author',
#                '/person/musician'],
#               ['/music'],
#               ['/person', '/person/actor', '/person/artist'],
#               ['/person',
#                '/person/actor',
#                '/person/artist',
#                '/person/musician'],
#               ['/music'],
#               ['/person',
#                '/person/artist',
#                '/person/author',
#                '/person/musician'],
#               ['/person', '/person/artist', '/person/musician'],
#               ['/person', '/person/artist', '/person/musician'],
#               ['/person'],
#               ['/person'],
#               ['/title'],
#               ['/person',
#                '/person/actor',
#                '/person/author',
#                '/person/politician',
#                '/person/soldier'],
#               ['/person',
#                '/person/actor',
#                '/person/artist',
#                '/person/musician'],
#               ['/music'],
#               ['/music'],
#               ['/person',
#                '/person/actor',
#                '/person/artist',
#                '/person/author',
#                '/person/director',
#                '/person/musician'],
#               ['/music'],
#               ['/person',
#                '/person/actor',
#                '/person/artist',
#                '/person/author',
#                '/person/musician'],
#               ['/person'],
#               ['/person', '/person/author'],
#               ['/people', '/people/ethnicity'],
#               ['/person',
#                '/person/actor',
#                '/person/artist',
#                '/person/author',
#                '/person/musician'],
#               ['/music'],
#               ['/person', '/person/artist', '/person/musician'],
#               ['/person',
#                '/person/actor',
#                '/person/artist',
#                '/person/musician'],
#               ['/music'],
#               ['/person', '/person/artist', '/person/musician'],
#               ['/person',
#                '/person/actor',
#                '/person/artist',
#                '/person/musician'],
#               ['/person', '/person/artist'],
#               ['/event'],
#               ['/language'],
#               ['/person', '/person/actor', '/person/artist'],
#               ['/person', '/person/author', '/person/politician'],
#               ['/broadcast_program'],
#               ['/person', '/person/actor'],
#               ['/event'],
#               ['/language'],
#               ['/organization', '/religion', '/religion/religion'],
#               ['/religion', '/religion/religion'],
#               ['/person', '/person/author', '/person/politician'],
#               ['/news_agency',
#                '/organization',
#                '/organization/company',
#                '/person',
#                '/person/engineer'],
#               ['/language'],
#               ['/person', '/person/artist', '/person/musician'],
#               ['/person',
#                '/person/actor',
#                '/person/artist',
#                '/person/author',
#                '/person/musician'],
#               ['/music'],
#               ['/organization', '/organization/company'],
#               ['/music'],
#               ['/person',
#                '/person/actor',
#                '/person/artist',
#                '/person/musician'],
#               ['/music'],
#               ['/music'],
#               ['/organization'],
#               ['/person', '/person/artist'],
#               ['/person', '/person/artist'],
#               ['/music'],
#               ['/person',
#                '/person/actor',
#                '/person/artist',
#                '/person/musician'],
#               ['/person', '/person/author'],
#               ['/person', '/person/actor', '/person/artist'],
#               ['/person', '/person/artist'],
#               ['/person', '/person/author'],
#               ['/person', '/person/artist', '/person/musician'],
#               ['/person', '/person/artist', '/person/musician'],
#               ['/language'],
#               ['/person',
#                '/person/artist',
#                '/person/author',
#                '/person/musician'],
#               ['/person'],
#               ['/person', '/person/actor', '/person/artist', '/person/author'],
#               ['/music'],
#               ['/person',
#                '/person/actor',
#                '/person/artist',
#                '/person/author',
#                '/person/musician'],
#               ['/person',
#                '/person/actor',
#                '/person/artist',
#                '/person/musician'],
#               ['/music'],
#               ['/person', '/person/actor', '/person/artist'],
#               ['/astral_body'],
#               ['/astral_body'],
#               ['/person', '/person/artist', '/person/musician'],
#               ['/person'],
#               ['/event'],
#               ['/person', '/person/artist', '/person/musician'],
#               ['/person',
#                '/person/actor',
#                '/person/artist',
#                '/person/musician'],
#               ['/music'],
#               ['/person',
#                '/person/actor',
#                '/person/artist',
#                '/person/author',
#                '/person/musician'],
#               ['/game'],
#               ['/product', '/software'],
#               ['/organization',
#                '/organization/company',
#                '/person',
#                '/person/engineer'],
#               ['/organization'],
#               ['/game'],
#               ['/person', '/person/actor', '/person/athlete'],
#               ['/music'],
#               ['/person', '/person/artist', '/person/musician'],
#               ['/organization', '/organization/company'],
#               ['/organization'],
#               ['/news_agency',
#                '/organization',
#                '/organization/company',
#                '/person',
#                '/person/author',
#                '/written_work'],
#               ['/music'],
#               ['/person',
#                '/person/actor',
#                '/person/artist',
#                '/person/musician'],
#               ['/music'],
#               ['/game'],
#               ['/person', '/person/artist', '/person/musician'],
#               ['/person', '/person/actor', '/person/artist'],
#               ['/person', '/person/author', '/written_work'],
#               ['/written_work'],
#               ['/person', '/person/artist', '/person/musician'],
#               ['/person',
#                '/person/actor',
#                '/person/artist',
#                '/person/musician'],
#               ['/person', '/person/author'],
#               ['/organization',
#                '/organization/company',
#                '/person',
#                '/person/artist'],
#               ['/person',
#                '/person/actor',
#                '/person/artist',
#                '/person/author',
#                '/person/musician'],
#               ['/music'],
#               ['/broadcast_program'],
#               ['/person',
#                '/person/actor',
#                '/person/artist',
#                '/person/author',
#                '/person/director'],
#               ['/organization', '/organization/company'],
#               ['/person'],
#               ['/person', '/person/actor', '/person/artist'],
#               ['/music'],
#               ...]})

# %%
types_only_partitions['only_father'].keys()
# Out:
# dict_keys(['/location'])
